# %%
import os
import pickle
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

from astropy import units as u 
from astropy.table import Table

from snewpy.neutrino import Flavor, MassHierarchy, MixingParameters
from snewpy.models import Nakazato_2013
from snewpy.models.ccsn import Fornax_2022
from snewpy.models.ccsn import Bollig_2016
from snewpy.models.ccsn import Sukhbold_2015
from snewpy.flavor_transformation import AdiabaticMSW, NonAdiabaticMSWH, \
                                         TwoFlavorDecoherence, ThreeFlavorDecoherence, \
                                         NeutrinoDecay, AdiabaticMSWes, NonAdiabaticMSWes
from asteria import set_rcparams
from asteria.simulation import Simulation


# %matplotlib inline
# Out:
# C:\Users\sanya\AppData\Local\Temp\ipykernel_14328\1358665751.py:11: FutureWarning: snewpy.models.Nakazato_2013 is moved to snewpy.models.ccsn.Nakazato_2013
#   from snewpy.models import Nakazato_2013

# %%
forn_masses=[9,10,11,12,13,14.01,15,16.99,18.04,19.02,19.99,21,22,23,24,25,26,26.99]

# %%
forn_param = list(params for params in Fornax_2022.get_param_combinations() if 
                   params['progenitor_mass'].value in forn_masses)
sukh_param_sfho=list(params for params in Sukhbold_2015.get_param_combinations() if params['eos']=='SFHo')
sukh_param_ls220=list(params for params in Sukhbold_2015.get_param_combinations() if params['eos']=='LS220')

# %%
sukh_param_ls220[0]
# Out:
# {'progenitor_mass': <Quantity 27. solMass>, 'eos': 'LS220'}

# %%
labels=['nmo','imo']

forn_sims = {
  9: [],
  10: [],
  11: [],
  12: [],
  13: [],
  14.01: [],
  15: [],
  16.99: [],
  18.04: [],
  19.02: [],
  19.99: [],
  21: [],
  22: [],
  23: [],
  24: [],
  25: [],
  26: [],
  26.99: []
}
# Out:
# <Quantity [ 9.  , 10.  , 11.  , 12.  , 12.13, 12.25, 12.5 , 12.7 , 12.85,
#            13.  , 13.27, 13.5 , 13.9 , 14.25, 14.44, 15.01, 16.43, 17.07,
#            17.5 , 18.05, 19.02, 20.08, 21.  , 22.82, 24.  ] solMass>

# %%
sukh_model_sfho_27 = {'name': 'Sukhbold_2015',
            'param': sukh_param_sfho[0]
              }

sukh_model_ls220_27 = {'name': 'Sukhbold_2015',
            'param': sukh_param_ls220[0]
              }

sukh_model_sfho_9 = {'name': 'Sukhbold_2015',
            'param': sukh_param_sfho[1]
              }

sukh_model_ls220_9 = {'name': 'Sukhbold_2015',
            'param': sukh_param_ls220[1]
              }

# %%
models=[sukh_model_sfho_27,sukh_model_ls220_27,sukh_model_sfho_9,sukh_model_ls220_9]
labels=['nmo','imo']
hie=['normal','inverted']
for i,mod in enumerate(models):
    for j,lab in enumerate(labels):
        pred = Simulation(model=mod,
                                         distance=10 * u.kpc, 
                                         Emin=0*u.MeV, Emax=100*u.MeV, dE=1*u.MeV,
                                         tmin=-10*u.s,  tmax=10*u.s,    dt=1*u.ms,
                                         mixing_scheme='AdiabaticMSW',
                                         hierarchy=hie[j])
        pred.run()
        with open("{}_M={}_eos={}_mix={}.pkl".format(mod['name'], mod['param']['progenitor_mass'].value,
                                                        mod['param']['eos'],
                                                        lab), 'wb') as f:
            pickle.dump(pred, f)
# Out:
# C:\Users\sanya\miniconda3\lib\site-packages\snewpy\models\base.py:302: RuntimeWarning: divide by zero encountered in log
#   np.exp(np.log(L) - (2+a)*np.log(Ea) + (1+a)*np.log(1+a)
# C:\Users\sanya\miniconda3\lib\site-packages\snewpy\models\base.py:302: RuntimeWarning: invalid value encountered in subtract
#   np.exp(np.log(L) - (2+a)*np.log(Ea) + (1+a)*np.log(1+a)
# C:\Users\sanya\miniconda3\lib\site-packages\snewpy\models\base.py:303: RuntimeWarning: divide by zero encountered in divide
#   - loggamma(1+a) + a*np.log(E) - (1+a)*(E/Ea)) / (u.erg * u.s)
# sukhbold-LS220-z9.6.fits:   0%|          | 0.00/619k [00:00<?, ?iB/s]

# %%
sukh_sfho_sims = {
    9.6:[],
    27.0:[]
}

sukh_ls220_sims = {
    9.6:[],
    27.0:[]
}
labels=['nmo','imo']
for i,mass in enumerate([9.6,27.0]):
    for j,lab in enumerate(labels):
        with open("Sukhbold_2015_M={}_eos=SFHo_mix={}.pkl".format(mass,
                                                    lab), 'rb') as f:
            sukh_sfho_sims[mass].append(pickle.load(f))
        with open("Sukhbold_2015_M={}_eos=LS220_mix={}.pkl".format(mass,
                                                    lab), 'rb') as f:
            sukh_ls220_sims[mass].append(pickle.load(f))

# %%
hits_sukh_sfho = {
    9.6:[],
    27.0:[]
}

hits_sukh_ls220 = {
    9.6:[],
    27.0:[]
}

dt=20*u.ms
#max_t_dat = t1[np.argmax(norm_data_hits[0])]
for i,mod in enumerate([9.6,27.0]):
    for j in range(2):
        simm_sfho=sukh_sfho_sims[mod][j]
        simm_sfho.rebin_result(dt)
        simm_sfho.scale_result(10*u.kpc)
        t, hits = simm_sfho.detector_signal(dt)
        id5=np.where(t==.02*u.s)[0][0]
        id6=np.where(t==1*u.s)[0][0]
        
        data=hits[id5:id6]
        hits_sukh_sfho[mod].append(data) 
        
        simm_ls220=sukh_ls220_sims[mod][j]
        simm_ls220.rebin_result(dt)
        simm_ls220.scale_result(10*u.kpc)
        t, hits = simm_ls220.detector_signal(dt)
        id5=np.where(t==.02*u.s)[0][0]
        id6=np.where(t==1*u.s)[0][0]
        
        data=hits[id5:id6]
        hits_sukh_ls220[mod].append(data)

# %%
sukh_sfho_nh_data = {
    9.6:[],
    27.0:[]
}

sukh_ls220_nh_data = {
    9.6:[],
    27.0:[]
}

dt=20*u.ms

for j,mod in enumerate([9.6,27.0]):
    for i in range(1000):
        data_sim_sfho=sukh_sfho_sims[mod][0]
        data_sim_sfho.rebin_result(dt)
        data_sim_sfho.scale_result(10*u.kpc)
        t, hits = data_sim_sfho.detector_signal(dt)
        bg1 = data_sim_sfho.detector.i3_bg(dt,size=hits.size) + data_sim_sfho.detector.dc_bg(dt,size=hits.size)
        sig=bg1+hits
        id1=np.where(t==-5*u.s)[0][0]
        id2=np.where(t==-.5*u.s)[0][0]
        id5=np.where(t==.02*u.s)[0][0]
        id6=np.where(t==1*u.s)[0][0]

        mean_under=np.mean(sig[id1:id2])
        data_hits=np.subtract(sig,mean_under)[id5:id6]
        sukh_sfho_nh_data[mod].append(data_hits)
        
        
        data_sim_ls220=sukh_ls220_sims[mod][0]
        data_sim_ls220.rebin_result(dt)
        data_sim_ls220.scale_result(10*u.kpc)
        t, hits = data_sim_ls220.detector_signal(dt)
        bg1 = data_sim_ls220.detector.i3_bg(dt,size=hits.size) + data_sim_ls220.detector.dc_bg(dt,size=hits.size)
        sig=bg1+hits
        id1=np.where(t==-5*u.s)[0][0]
        id2=np.where(t==-.5*u.s)[0][0]
        id5=np.where(t==.02*u.s)[0][0]
        id6=np.where(t==1*u.s)[0][0]

        mean_under=np.mean(sig[id1:id2])
        data_hits=np.subtract(sig,mean_under)[id5:id6]
        sukh_ls220_nh_data[mod].append(data_hits)

# %%
#dt = 10 * u.ms
colors_nmo=['#fc2b1c','#e6e602','#02cf13','#0232cf','#9200b3']
mod_names=['sukh_sfho','sukh_ls220','forn','zha','tamb']


plt.step(t[id5:id6], hits_sukh_sfho[9.6][0], where='post',color=colors_nmo[0],label=f'sfho NH')
plt.step(t[id5:id6], hits_sukh_sfho[9.6][1], where='post',color=colors_nmo[1],label=f'sfho IH')

plt.step(t[id5:id6], hits_sukh_ls220[9.6][0], where='post',color=colors_nmo[2],label=f'ls220 NH')
plt.step(t[id5:id6], hits_sukh_ls220[9.6][1], where='post',color=colors_nmo[3],label=f'ls220 IH')


plt.step(t[id5:id6], sukh_sfho_nh_data[9.6][0], where='post',color='orange',label='data sfho')
plt.step(t[id5:id6], sukh_ls220_nh_data[9.6][0], where='post',color='pink',label='data ls220')

    
plt.legend(loc='lower right')
plt.xlim(0,1)
plt.xlabel('Time (s)')
plt.ylabel('Total Signal')
plt.title('Signal for Sukhbold Models with M=9.6, d=10kpc, 10ms binning')
# Out:
# Text(0.5, 1.0, 'Signal for Sukhbold Models with M=9.6, d=10kpc, 10ms binning')

# %%
def compute_chi_sq(pred,dat):
    chi_sq=0
    for i in range(len(pred)):
        chi_sq += ((pred[i]-dat[i])**2)/(dat[i])
    return chi_sq

# %%
sukh_sfho_chi = {
    9.6:[],
    27.0:[]
}

sukh_ls220_chi = {
    9.6:[],
    27.0:[]
}

dt=10*u.ms

for j,mod in enumerate([9.6,27.0]):
    chi_nmo_sfho=[]
    chi_imo_sfho=[]
    chi_nmo_ls220=[]
    chi_imo_ls220=[]
    for i in range(1000):
        chi_nmo_sfho.append(compute_chi_sq(hits_sukh_sfho[mod][0],sukh_sfho_nh_data[mod][i]))
        chi_imo_sfho.append(compute_chi_sq(hits_sukh_sfho[mod][1],sukh_sfho_nh_data[mod][i]))
            
        chi_nmo_ls220.append(compute_chi_sq(hits_sukh_ls220[mod][0],sukh_ls220_nh_data[mod][i]))
        chi_imo_ls220.append(compute_chi_sq(hits_sukh_ls220[mod][1],sukh_ls220_nh_data[mod][i]))
            
    sukh_sfho_chi[mod].append(chi_nmo_sfho)
    sukh_sfho_chi[mod].append(chi_imo_sfho)
        
    sukh_ls220_chi[mod].append(chi_nmo_ls220)
    sukh_ls220_chi[mod].append(chi_imo_ls220)

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 15))
axes = axes.flatten()
masses=[9.6,27.0,9.6,27]

for i,ax in enumerate(axes):
    if(i<2):
        ax.hist(sukh_sfho_chi[masses[i]][0], alpha=0.5, color='#fa8787', edgecolor='#a35656', 
                linewidth=1.5,label='NH',bins=16)
        ax.hist(sukh_sfho_chi[masses[i]][1], alpha=0.5, color='#90fcad', edgecolor='#02b031', 
                linewidth=1.5,label='IH',bins=16)
        ax.legend()
        ax.set_xlabel('Chi Sq Distance')
        ax.set_ylabel('Counts')
        ax.set_title('Chi Sq for Sukhbold SFHo, M={}'.format(masses[i]))
        
    else:
        ax.hist(sukh_ls220_chi[masses[i]][0], alpha=0.5, color='#fa8787', edgecolor='#a35656', 
                    linewidth=1.5,label='NH',bins=16)
        ax.hist(sukh_ls220_chi[masses[i]][1], alpha=0.5, color='#90fcad', edgecolor='#02b031', 
                    linewidth=1.5,label='IH',bins=16)
        ax.legend()
        ax.set_xlabel('Chi Sq Distance')
        ax.set_ylabel('Counts')
        ax.set_title('Chi Sq for Sukhbold LS220, M={}'.format(masses[i]))

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 15))
axes = axes.flatten()
masses=[9.6,27.0,9.6,27]

for i,ax in enumerate(axes):
    if(i<2):
        ax.hist(sukh_sfho_chi[masses[i]][0], alpha=0.5, color='#fa8787', edgecolor='#a35656', 
                linewidth=1.5,label='NH',bins=16)
        ax.hist(sukh_sfho_chi[masses[i]][1], alpha=0.5, color='#90fcad', edgecolor='#02b031', 
                linewidth=1.5,label='IH',bins=16)
        ax.legend()
        ax.set_xlabel('Chi Sq Distance')
        ax.set_ylabel('Counts')
        ax.set_yscale('log')
        ax.set_title('Chi Sq for Sukhbold SFHo, M={}'.format(masses[i]))
        
    else:
        ax.hist(sukh_ls220_chi[masses[i]][0], alpha=0.5, color='#fa8787', edgecolor='#a35656', 
                linewidth=1.5,label='NH',bins=16)
        ax.hist(sukh_ls220_chi[masses[i]][1], alpha=0.5, color='#90fcad', edgecolor='#02b031', 
                linewidth=1.5,label='IH',bins=16)
        ax.legend()
        ax.set_xlabel('Chi Sq Distance')
        ax.set_ylabel('Counts')
        ax.set_yscale('log')
        ax.set_title('Chi Sq for Sukhbold LS220, M={}'.format(masses[i]))

# %%
from scipy.optimize import curve_fit
def quad_fit(x,a,b):
    return a*x + b

nbins=16
hist_nh, bin_edges_nh = np.histogram(sukh_ls220_chi[9.6][0], bins=nbins)
hist_ih, bin_edges_ih = np.histogram(sukh_ls220_chi[9.6][1], bins=nbins)

tail_region = slice(-12, None)

params_nh, cov_nh = curve_fit(quad_fit, bin_edges_nh[1:][tail_region], np.log(hist_nh[tail_region]+1))
params_ih, cov_ih = curve_fit(quad_fit, bin_edges_ih[1:][tail_region], np.log(hist_ih[tail_region]+1))

a_nh, b_nh = params_nh
a_ih, b_ih = params_ih
          
x_nh=np.linspace(bin_edges_nh[1:][-10],6000,500)
x_ih=np.linspace(bin_edges_ih[1:][-10],12000,500)
y_fit_nh = np.exp(a_nh*x_nh+b_nh)
y_fit_ih = np.exp(a_ih*x_ih+b_ih)

                             
plt.hist(sukh_ls220_chi[9.6][0], alpha=0.5, color='#fa8787', edgecolor='#a35656', 
                linewidth=1.5,label='NH',bins=nbins)
plt.hist(sukh_ls220_chi[9.6][1], alpha=0.5, color='#90fcad', edgecolor='#02b031', 
                linewidth=1.5,label='IH',bins=nbins)

plt.plot(x_nh, y_fit_nh, color='red', label='NH fit')
plt.plot(x_ih, y_fit_ih, color='blue', label='IH fit') 

plt.legend()

# %%
from scipy.optimize import curve_fit
def quad_fit(x,a,b):
    return a*x + b

nbins=40
hist_nh, bin_edges_nh = np.histogram(sukh_sfho_chi[9.6][0], bins=nbins)
hist_ih, bin_edges_ih = np.histogram(sukh_sfho_chi[9.6][1], bins=nbins)

cumulative_nh = np.cumsum(hist_nh)
cumulative_ih = np.cumsum(hist_ih)

split_nh = np.searchsorted(cumulative_nh, 900)
split_ih = np.searchsorted(cumulative_ih, 900)

tail_region_nh = slice(-(len(hist_nh)-split_nh), None)
tail_region_ih = slice(-(len(hist_ih)-split_ih), None)

params_nh, cov_nh = curve_fit(quad_fit, bin_edges_nh[1:][tail_region_nh], np.log(hist_nh[tail_region_nh]+1))
params_ih, cov_ih = curve_fit(quad_fit, bin_edges_ih[1:][tail_region_ih], np.log(hist_ih[tail_region_ih]+1))

a_nh, b_nh = params_nh
a_ih, b_ih = params_ih
          
x_nh=np.linspace(bin_edges_nh[1:][-(len(bin_edges_nh)-split_nh)],6000,500)
x_ih=np.linspace(bin_edges_ih[1:][-(len(bin_edges_ih)-split_ih)],12000,500)
y_fit_nh = np.exp(a_nh*x_nh+b_nh)
y_fit_ih = np.exp(a_ih*x_ih+b_ih)

                             
plt.hist(sukh_sfho_chi[9.6][0], alpha=0.5, color='#fa8787', edgecolor='#a35656', 
                linewidth=1.5,label='NH',bins=nbins)
plt.hist(sukh_sfho_chi[9.6][1], alpha=0.5, color='#90fcad', edgecolor='#02b031', 
                linewidth=1.5,label='IH',bins=nbins)

plt.plot(x_nh, y_fit_nh, color='red', label='NH fit')
plt.plot(x_ih, y_fit_ih, color='blue', label='IH fit') 
#plt.yscale('log')

plt.legend()

# %%
def compute_p_val(area_tot,start,params,stat):
    a,b=params
    upper=-1/a*(60+b)
    lower=stat
    area=1/a*(np.exp(a*upper+b)-np.exp(a*lower+b))
    area_full=.9*area_tot + 1/a*(np.exp(a*upper+b)-np.exp(a*start+b))
    return area/area_full

# %%
compute_p_val(1000,bin_edges_nh[split_nh],params_nh,5000)
# Out:
# 0.29671296534883956

# %%
def dist_to_pval(data,nh,ih,nbins):
    chis_nh=[]
    chis_ih=[]
    for i, dat in enumerate(data):
        chis_nh.append(compute_chi_sq(nh,dat))
        chis_ih.append(compute_chi_sq(ih,dat))
    
    hist_nh, bin_edges_nh = np.histogram(chis_nh, bins=nbins)
    hist_ih, bin_edges_ih = np.histogram(chis_ih, bins=nbins)

    cumulative_nh = np.cumsum(hist_nh)
    split_nh = np.searchsorted(cumulative_nh, .9*len(data))

    tail_region_nh = slice(-(len(hist_nh)-split_nh), None)

    params_nh, cov_nh = curve_fit(quad_fit, bin_edges_nh[1:][tail_region_nh], np.log(hist_nh[tail_region_nh]+1))
    a_nh, b_nh = params_nh
    
    p_vals=[]
    for i,chi_ih in enumerate(chis_ih):
        p=compute_p_val(len(data),bin_edges_nh[split_nh],params_nh,chi_ih)
        p_vals.append(p)
        
    return p_vals

# %%
np.median(dist_to_pval(sukh_sfho_nh_data[9.6],hits_sukh_sfho[9.6][0],hits_sukh_sfho[9.6][1],24))
# Out:
# 0.27089674567088323

# %%
-1/a*(50+b)
# Out:
# 9710.196691896766

# %%
1/a*(np.exp(a*upper+b)-np.exp(a*bin_edges_nh[split_nh]+b))
# Out:
# 62980.69901940658

# %%
np.exp(-15)
# Out:
# 3.059023205018258e-07

# %% [markdown]
# # Trick to Convert a p-value to Gaussian Sigma
#
# This uses the "survival function" of the Guassian PDF to convert arbitrary p-values to equivalent multiples of the sigma of a normal distribution.

# %%
from scipy.stats import norm

# %%
#- Survival function: convert sigma to tail probability (p-value)
norm.sf(5)
# Out:
# 2.866515718791933e-07

# %%
#- Inverse survival function: convert tail probability to sigma
norm.isf(.29)
# Out:
# 0.5533847195556729

# %%
norm.isf(1e-25)
# Out:
# 10.420452200803098
